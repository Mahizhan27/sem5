# %%
import pandas as pd

# %%
data=pd.read_csv("C:/Users/ADMIN/Downloads/archive (1)/covid_19_india.csv")

# %%
data
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 18105  18106  2021-08-11  8:00 AM            Telangana
# 18106  18107  2021-08-11  8:00 AM              Tripura
# 18107  18108  2021-08-11  8:00 AM          Uttarakhand
# 18108  18109  2021-08-11  8:00 AM        Uttar Pradesh
# 18109  18110  2021-08-11  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %%
pip install numpy<2
# Out:
# Note: you may need to restart the kernel to use updated packages.
# The system cannot find the file specified.

# %%
pip install --upgrade matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as pt
# %matplotlib inline

# %%
pt.scatter(data["State/UnionTerritory"],data["ConfirmedForeignNational"])

# %%
pt.plot(data["State/UnionTerritory"],data["ConfirmedIndianNational"])

# %%
pt.bar((data["ConfirmedIndianNational"][:7]),(data["Confirmed"][:7]))
# Out:
# <BarContainer object of 7 artists>

# %%
pt.pie((data["ConfirmedIndianNational"][:7]),labels =(data["Confirmed"][:7]))
# Out:
# ([<matplotlib.patches.Wedge at 0x21a10456a30>,
# ...
#  [Text(1.078863807270999, 0.21459936011257072, '1'),
#   Text(0.9146165726218474, 0.6111272576848992, '1'),
#   Text(0.4209517725718817, 1.0162674870173654, '2'),
#   Text(-0.6111274066948447, 0.9146164730565671, '3'),
#   Text(-1.078863772521214, -0.21459953481145866, '3'),
#   Text(-0.21459942762886586, -1.0788637938411703, '3'),
#   Text(0.9146165337706407, -0.6111273158298348, '3')])
